# %% [markdown]
# <a href="https://colab.research.google.com/github/ivashenceva220495-beep/My_first_repository/blob/main/DZ2_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание 1
#
#
# Дана переменная, в которой хранится слово из латинских букв. Напишите код, который выводит на экран:
#
# среднюю букву, если число букв в слове нечетное;
# две средних буквы, если число букв четное.

# %%
word = str(input("Введите слово: "));
len_word = len(word);
middle = len_word//2;
if len_word %2 == 0:
    print ('Слово четное и две средних буквы: '+ word[middle] + word[middle +1]);
else:
    print('Слово нечетное и средняя буква:  ' + word[middle]);
# Out:
# Введите слово: слово
# Слово нечетное и средняя буква:  о

# %% [markdown]
# Задание 2
#
# Напишите программу, которая последовательно запрашивает у пользователя числа (по одному за раз) и после первого нуля выводит сумму всех ранее введенных чисел.

# %%
sum = 0
while True:
  my_integer = int(input("Введите число: "));
  if (my_integer !=0):
    sum = sum + my_integer;
    print (sum);
  else:
    print ('Пользователь ввел значение = 0');
    break;
# Out:
# Введите число: 1
# 1
# Введите число: 3
# 4
# Введите число: 4
# 8
# Введите число: 0
# Пользователь ввел значение = 0

# %% [markdown]
# Задание 3
#
#
# Мы делаем MVP dating-сервиса, и у нас есть список парней и девушек.
# Выдвигаем гипотезу: лучшие рекомендации мы получим, если просто отсортируем имена по алфавиту и познакомим людей с одинаковыми индексами после сортировки! Но мы не будем никого знакомить, если кто-то может остаться без пары:

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']


boys.sort();
girls.sort();

for boys_and_girls in  zip(boys, girls):
  if(len(boys) == len(girls)):
    print('Идеальная пара: ' + str(boys_and_girls));
  else:
    print('Внимание, кто-то может остаться без пары!');
    break;
# Out:
# Идеальная пара: ('Alex', 'Emma')
# Идеальная пара: ('Arthur', 'Kate')
# Идеальная пара: ('John', 'Kira')
# Идеальная пара: ('Peter', 'Liza')
# Идеальная пара: ('Richard', 'Trisha')

# %% [markdown]
# Задание 4
#
#
# У нас есть список, содержащий информацию о среднедневной температуре в Фаренгейтах за произвольный период по странам (структура данных в примере). Необходимо написать код, который рассчитает среднюю температуру за период в Цельсиях(!) для каждой страны.

# %%
#t °С = 5/9 (t °F - 32)

countries_temperature = [
    ['Таиланд', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
    ['Германия', [57.2, 55.4, 59, 59, 53.6]],
    ['Россия', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
    ['Польша', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]

avg_temperature = []
for country, temperatures in countries_temperature: #разделили список на два списка (страны, температуры)
    temperatures_celcius = [(temp - 32) *5/9 for temp in temperatures] # сделали список с температурами по цельсию
    avg_temperature.append([country, round(sum(temperatures_celcius) / len(temperatures)),1])
print(avg_temperature)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-b2ae9bf6fbf7> in <cell line: 11>()
#      11 for country, temperatures in countries_temperature: #разделили список на два списка (страны, температуры)
#      12     temperatures_celcius = [(temp - 32) *5/9 for temp in temperatures] # сделали список с температурами по цельсию
# ---> 13     avg_temperature.append([country, round(sum(temperatures_celcius) / len(temperatures)),1])
#      14 print(avg_temperature)
#
# TypeError: 'int' object is not callable
