# %% [markdown]
# <a href="https://colab.research.google.com/github/ivashenceva220495-beep/My_first_repository/blob/main/ML_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D1%81%D0%BE_%D0%B7%D0%B2%D0%B5%D0%B7%D0%B4%D0%BE%D1%87%D0%BA%D0%BE%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Загружаем необходимые библиотеки

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Загружаем данные (экспорт таблицы)

# %%
# Загрузите данные из файла insurance.csv в переменную df
df = pd.read_csv('ML_ДЗ - Лист1-2.csv' , sep=',')

# %%
df.head()
# Out:
#   категория  траты в позапрошлом месяце  траты в прошлом месяце  \
# 0  обучение                     10000.0                  5000.0
# 1    одежда                     20000.0                  5000.0
# 2  медицина                     15000.0                 20000.0
#
#    траты в текущем месяце  траты в следующем месяце
# 0                 30000.0                   50000.0
# 1                 15000.0                   10000.0
# 2                 10000.0                   15000.0

# %% [markdown]
# Смотрим статистику, что нет пропусков и отсутствующих значений

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   категория                   3 non-null      object
#  1   траты в позапрошлом месяце  3 non-null      float64
#  2   траты в прошлом месяце      3 non-null      float64
#  3   траты в текущем месяце      3 non-null      float64
#  4   траты в следующем месяце    3 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 248.0+ bytes

# %%
df.describe()
# Out:
#        траты в позапрошлом месяце  траты в прошлом месяце  \
# count                         3.0                3.000000
# mean                      15000.0            10000.000000
# std                        5000.0             8660.254038
# min                       10000.0             5000.000000
# 25%                       12500.0             5000.000000
# 50%                       15000.0             5000.000000
# 75%                       17500.0            12500.000000
# max                       20000.0            20000.000000
#
#        траты в текущем месяце  траты в следующем месяце
# count                3.000000                  3.000000
# mean             18333.333333              25000.000000
# std              10408.329997              21794.494718
# min              10000.000000              10000.000000
# 25%              12500.000000              12500.000000
# 50%              15000.000000              15000.000000
# ...

# %% [markdown]
# Преобразуем строковые данные

# %%
#Заменяем категорию на числа
df['категория'] = df['категория'].map({'обучение':0, 'одежда':1, 'медицина':2})

# %%
df.head()
# Out:
#    категория  траты в позапрошлом месяце  траты в прошлом месяце  \
# 0          0                     10000.0                  5000.0
# 1          1                     20000.0                  5000.0
# 2          2                     15000.0                 20000.0
#
#    траты в текущем месяце  траты в следующем месяце
# 0                 30000.0                   50000.0
# 1                 15000.0                   10000.0
# 2                 10000.0                   15000.0

# %% [markdown]
# Формируем признаки и целевую переменную

# %%
df.columns
# Out:
# Index(['категория', 'траты в позапрошлом месяце', 'траты в прошлом месяце',
#        'траты в текущем месяце', 'траты в следующем месяце'],
#       dtype='object')

# %%
X = df[['категория', 'траты в позапрошлом месяце', 'траты в прошлом месяце',
       'траты в текущем месяце']]
y = df['траты в следующем месяце']

# %%
X
# Out:
#    категория  траты в позапрошлом месяце  траты в прошлом месяце  \
# 0          0                     10000.0                  5000.0
# 1          1                     20000.0                  5000.0
# 2          2                     15000.0                 20000.0
#
#    траты в текущем месяце
# 0                 30000.0
# 1                 15000.0
# 2                 10000.0

# %%
y
# Out:
# 0    50000.0
# 1    10000.0
# 2    15000.0
# Name: траты в следующем месяце, dtype: float64

# %% [markdown]
# Разделяем данные на выборки: выборка для обучения, выборка для проверки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
X_train
# Out:
#    категория  траты в позапрошлом месяце  траты в прошлом месяце  \
# 1          1                     20000.0                  5000.0
#
#    траты в текущем месяце
# 1                 15000.0

# %%
X_test
# Out:
#    категория  траты в позапрошлом месяце  траты в прошлом месяце  \
# 2          2                     15000.0                 20000.0
# 0          0                     10000.0                  5000.0
#
#    траты в текущем месяце
# 2                 10000.0
# 0                 30000.0

# %%
y_train
# Out:
# 1    10000.0
# Name: траты в следующем месяце, dtype: float64

# %%
y_test
# Out:
# 2    15000.0
# 0    50000.0
# Name: траты в следующем месяце, dtype: float64

# %% [markdown]
# Создаем и обучаем модель

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Получаем предсказание и оцениваем

# %%
lr.predict(X_test)
# Out:
# array([10000., 10000.])

# %%
# Оцените качество, при помощи метода mean_squared_error для тестовой выборки
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 812500000.0

# %%
mean_squared_error(y_train, lr.predict(X_train))
# Out:
# 0.0

# %% [markdown]
# Делаем предсказание для одной категории

# %%
data = [{
         'категория': 1,
         'траты в позапрошлом месяце': 20000,
         'траты в прошлом месяце': 15000,
         'траты в текущем месяце': 5000

}]

# %%
df_category = pd.DataFrame(data)
df_category.head()
# Out:
#    категория  траты в позапрошлом месяце  траты в прошлом месяце  \
# 0          1                       20000                   15000
#
#    траты в текущем месяце
# 0                    5000

# %%
lr.predict(df_category)
# Out:
# array([10000.])
