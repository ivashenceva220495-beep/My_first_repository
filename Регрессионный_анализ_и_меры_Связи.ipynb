# %% [markdown]
# <a href="https://colab.research.google.com/github/ivashenceva220495-beep/My_first_repository/blob/main/%D0%A0%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%81%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B9_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B8_%D0%BC%D0%B5%D1%80%D1%8B_%D0%A1%D0%B2%D1%8F%D0%B7%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('FPS_lecture_df_0_height-weignt (2).xlsx')
df.head()
# Out:
#       ID  Gender      Height     Weight
# 0  10001    Male  174.782639  78.652188
# 1  10002  Female  165.183571  74.332607
# 2  10003    Male  181.542046  81.693920
# 3  10004  Female  167.845912  75.530661
# 4  10005  Female  160.475255  72.213865

# %%
#Формирование выборок
df_1 = df[df['Gender'] == 'Male']
df_2 = df[df['Gender'] == 'Female']

print ('Выборки имеют одинаковую длину: ', len(df_1) == len(df_2))
# Out:
# Выборки имеют одинаковую длину:  True

# %%
# описательная статистика мужчин
df_1.describe()
# Out:
#                  ID       Height       Weight
# count   1000.000000  1000.000000  1000.000000
# mean   11002.281000   175.655759    79.045091
# std      580.298598     7.331049     3.298972
# min    10001.000000   153.429654    69.043344
# 25%    10498.000000   170.757381    76.840822
# 50%    11000.500000   175.575025    79.008761
# 75%    11506.250000   180.612933    81.275820
# max    11998.000000   195.283831    87.877724

# %%
# описательная статистика женщин
df_2.describe()
# Out:
#                  ID       Height       Weight
# count   1000.000000  1000.000000  1000.000000
# mean   10998.719000   161.420314    72.639141
# std      574.961756     6.834302     3.075436
# min    10002.000000   138.387486    62.274369
# 25%    10503.750000   156.704763    70.517143
# 50%    11000.500000   161.494158    72.672371
# 75%    11496.500000   165.859545    74.636795
# max    12000.000000   186.460992    83.907447

# %%
#визуализация пересечения интервалов веса мужчин и женщин
sns.distplot(df_1['Weight'],50)
sns.distplot(df_2['Weight'],50)
plt.title('Плотность распределения веса')
plt.legend (['Male','Female'])
plt.show()
# Out:
# <ipython-input-11-b7a00b82a6dd>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1['Weight'],50)
# <ipython-input-11-b7a00b82a6dd>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2['Weight'],50)

# %%
#Функция бинарной классификации по признаку пола
def func_bin_gender(row):
  if row['Gender'] == 'Male':
    return 1
  elif row['Gender'] == 'Female':
    return 0

# %%
#Добавление столбца бинарной классификации пола
df['Gender(bin)'] = df.apply(func_bin_gender,axis = 1)
df
# Out:
#          ID  Gender      Height     Weight  Gender(bin)
# 0     10001    Male  174.782639  78.652188            1
# 1     10002  Female  165.183571  74.332607            0
# 2     10003    Male  181.542046  81.693920            1
# 3     10004  Female  167.845912  75.530661            0
# 4     10005  Female  160.475255  72.213865            0
# ...     ...     ...         ...        ...          ...
# 1995  11996    Male  184.224224  82.900901            1
# 1996  11997    Male  180.164315  81.073942            1
# 1997  11998    Male  173.442407  78.049083            1
# 1998  11999  Female  164.588728  74.064928            0
# 1999  12000  Female  164.074454  73.833504            0
#
# [2000 rows x 5 columns]

# %%
#Корреляция роста к весу
df['Height'].corr(df['Weight'])
# Out:
# 1.0

# %%
#Корреляция пола к росту
df['Gender(bin)'].corr(df['Height'])
# Out:
# 0.7088094753460076

# %%
#Корреляция пола к весу
df['Gender(bin)'].corr(df['Weight'])
# Out:
# 0.7088094753460076

# %%
#Матрица корреляции средствами пандас
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <ipython-input-20-af4c3c27893c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient(cmap='coolwarm')
# <style type="text/css">
# #T_868c3_row0_col0, #T_868c3_row1_col1, #T_868c3_row1_col2, #T_868c3_row2_col1, #T_868c3_row2_col2, #T_868c3_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_868c3_row0_col1, #T_868c3_row0_col2, #T_868c3_row0_col3, #T_868c3_row1_col0, #T_868c3_row2_col0, #T_868c3_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_868c3_row1_col3, #T_868c3_row2_col3, #T_868c3_row3_col1, #T_868c3_row3_col2 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# </style>
# <table id="T_868c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
#Матрица корреляции средствами визуализации seaborn (тепловая матрица)
sns.heatmap (df.corr(), annot = True, vmin = -1, vmax =1,center = 0,cmap = 'coolwarm')
# Out:
# <ipython-input-31-543a25016d82>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap (df.corr(), annot = True, vmin = -1, vmax =1,center = 0,cmap = 'coolwarm')
# <Axes: >

# %% [markdown]
# Построение линейной регрессии  - моделирование и анализ взаимосвязей переменных

# %%
# формирование выборок роста и веса для мужчин
x = df_1[['Height']]
y = df_1[['Weight']]

# %%
from sklearn.linear_model import LinearRegression # подключение модуля линейной регрессии
regressor = LinearRegression()                    # инициализация линейной регрессии
regressor.fit (x,y)                               # обучение линейной регрессии
# Out:
# LinearRegression()

# %%
# Коэффициент прямой
a = regressor.intercept_
a
# Out:
# array([-1.42108547e-14])

# %%
# Коэффициент наклона прямой
b = regressor.coef_
b
# Out:
# array([[0.45]])

# %%
Height_pred = 170 #Значение роста для получения прогноза веса
regressor.predict ([[Height_pred]]) # Получение прогноза линейной регрессии
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[76.5]])

# %%
# Получение прогноза "в лоб" по уравнению прямой регрессии а + bx
a + b * Height_pred
# Out:
# array([[76.5]])

# %% [markdown]
# Построение линейной регрессии для женщин
